# %%
from git import Repo
import os
import subprocess
import shutil

# %%
version_jdk = {
    'v7.0.0': "",
 'v7.0.0-alpha1': "",
 'v7.0.0-alpha2': "",
 'v7.0.0-beta1': "",
 'v7.0.0-rc1': "",
 'v7.0.0-rc2': "",
 'v7.0.1': "",
 'v7.1.0': "",
 'v7.1.1': "",
 'v7.2.0': "",
 'v7.2.1': "",
 'v7.3.0': "",
 'v7.3.1': "",
 'v7.3.2': "",
 'v7.4.0': "",
 'v7.4.1': "",
 'v7.4.2': "",
 'v7.5.0': "",
 'v7.5.1': "",
 'v7.5.2': "",
 'v7.6.0': "",
 'v7.6.1': "/Library/Java/JavaVirtualMachines/openjdk-14.0.2.jdk/Contents/Home",
 'v7.6.2': "/Library/Java/JavaVirtualMachines/openjdk-14.0.2.jdk/Contents/Home",
 'v7.7.0': "/Library/Java/JavaVirtualMachines/openjdk-14.0.2.jdk/Contents/Home",
 'v7.7.1': "/Library/Java/JavaVirtualMachines/jdk-13.0.2.jdk/Contents/Home",
 'v7.8.0': "/Library/Java/JavaVirtualMachines/jdk-13.0.2.jdk/Contents/Home",
 'v7.8.1': "/Library/Java/JavaVirtualMachines/jdk-13.0.2.jdk/Contents/Home"
}

# %%
repo = Repo("/Users/alexincerti/Code/elasticsearch")

# %%
git = repo.git

# %%
tags = list(repo.tags)

# %%
[tag.name for tag in tags]
# Out:
# ['v0.10.0',
#  'v0.11.0',
#  'v0.12.0',
#  'v0.12.1',
#  'v0.13.0',
#  'v0.13.1',
#  'v0.14.0',
#  'v0.14.1',
#  'v0.14.2',
#  'v0.14.3',
#  'v0.14.4',
#  'v0.15.0',
#  'v0.15.1',
#  'v0.15.2',
#  'v0.16.0',
#  'v0.16.1',
#  'v0.16.2',
#  'v0.16.3',
#  'v0.16.4',
#  'v0.16.5',
#  'v0.17.0',
#  'v0.17.1',
#  'v0.17.10',
#  'v0.17.2',
#  'v0.17.3',
#  'v0.17.4',
#  'v0.17.5',
#  'v0.17.6',
#  'v0.17.7',
#  'v0.17.8',
#  'v0.17.9',
#  'v0.18.0',
#  'v0.18.1',
#  'v0.18.2',
#  'v0.18.3',
#  'v0.18.4',
#  'v0.18.5',
#  'v0.18.6',
#  'v0.18.7',
#  'v0.19.0',
#  'v0.19.0.RC1',
#  'v0.19.0.RC2',
#  'v0.19.0.RC3',
#  'v0.19.1',
#  'v0.19.10',
#  'v0.19.11',
#  'v0.19.12',
#  'v0.19.2',
#  'v0.19.3',
#  'v0.19.4',
#  'v0.19.5',
#  'v0.19.6',
#  'v0.19.7',
#  'v0.19.8',
#  'v0.19.9',
#  'v0.20.0',
#  'v0.20.0.RC1',
#  'v0.20.1',
#  'v0.20.2',
#  'v0.20.3',
#  'v0.20.4',
#  'v0.20.5',
#  'v0.20.6',
#  'v0.4.0',
#  'v0.5.0',
#  'v0.5.1',
#  'v0.6.0',
#  'v0.7.0',
#  'v0.7.1',
#  'v0.8.0',
#  'v0.9.0',
#  'v0.90.0',
#  'v0.90.0.Beta1',
#  'v0.90.0.RC1',
#  'v0.90.0.RC2',
#  'v0.90.1',
#  'v0.90.10',
#  'v0.90.11',
#  'v0.90.12',
#  'v0.90.13',
#  'v0.90.2',
#  'v0.90.3',
#  'v0.90.4',
#  'v0.90.5',
#  'v0.90.6',
#  'v0.90.7',
#  'v0.90.8',
#  'v0.90.9',
#  'v1.0.0',
#  'v1.0.0.Beta1',
#  'v1.0.0.Beta2',
#  'v1.0.0.RC1',
#  'v1.0.0.RC2',
#  'v1.0.1',
#  'v1.0.2',
#  'v1.0.3',
#  'v1.1.0',
#  'v1.1.1',
#  'v1.1.2',
#  'v1.2.0',
#  'v1.2.1',
#  'v1.2.2',
#  'v1.2.3',
#  'v1.2.4',
#  'v1.3.0',
#  'v1.3.1',
#  'v1.3.2',
#  'v1.3.3',
#  'v1.3.4',
#  'v1.3.5',
#  'v1.3.6',
#  'v1.3.7',
#  'v1.3.8',
#  'v1.3.9',
#  'v1.4.0',
#  'v1.4.0.Beta1',
#  'v1.4.1',
#  'v1.4.2',
#  'v1.4.3',
#  'v1.4.4',
#  'v1.4.5',
#  'v1.5.0',
#  'v1.5.1',
#  'v1.5.2',
#  'v1.6.0',
#  'v1.6.1',
#  'v1.6.2',
#  'v1.7.0',
#  'v1.7.1',
#  'v1.7.2',
#  'v1.7.3',
#  'v1.7.4',
#  'v1.7.5',
#  'v1.7.6',
#  'v2.0.0',
#  'v2.0.0-beta1',
#  'v2.0.0-beta2',
#  'v2.0.0-rc1',
#  'v2.0.1',
#  'v2.0.2',
#  'v2.1.0',
#  'v2.1.1',
#  'v2.1.2',
#  'v2.2.0',
#  'v2.2.1',
#  'v2.2.2',
#  'v2.3.0',
#  'v2.3.1',
#  'v2.3.2',
#  'v2.3.3',
#  'v2.3.4',
#  'v2.3.5',
#  'v2.4.0',
#  'v2.4.1',
#  'v2.4.2',
#  'v2.4.3',
#  'v2.4.4',
#  'v2.4.5',
#  'v2.4.6',
#  'v5.0.0',
#  'v5.0.0-alpha1',
#  'v5.0.0-alpha2',
#  'v5.0.0-alpha3',
#  'v5.0.0-alpha4',
#  'v5.0.0-alpha5',
#  'v5.0.0-beta1',
#  'v5.0.0-rc1',
#  'v5.0.1',
#  'v5.0.2',
#  'v5.1.1',
#  'v5.1.2',
#  'v5.2.0',
#  'v5.2.1',
#  'v5.2.2',
#  'v5.3.0',
#  'v5.3.1',
#  'v5.3.2',
#  'v5.3.3',
#  'v5.4.0',
#  'v5.4.1',
#  'v5.4.2',
#  'v5.4.3',
#  'v5.5.0',
#  'v5.5.1',
#  'v5.5.2',
#  'v5.5.3',
#  'v5.6.0',
#  'v5.6.1',
#  'v5.6.10',
#  'v5.6.11',
#  'v5.6.12',
#  'v5.6.13',
#  'v5.6.14',
#  'v5.6.15',
#  'v5.6.16',
#  'v5.6.2',
#  'v5.6.3',
#  'v5.6.4',
#  'v5.6.5',
#  'v5.6.6',
#  'v5.6.7',
#  'v5.6.8',
#  'v5.6.9',
#  'v6.0.0',
#  'v6.0.0-alpha1',
#  'v6.0.0-alpha2',
#  'v6.0.0-beta1',
#  'v6.0.0-beta2',
#  'v6.0.0-rc1',
#  'v6.0.0-rc2',
#  'v6.0.1',
#  'v6.1.0',
#  'v6.1.1',
#  'v6.1.2',
#  'v6.1.3',
#  'v6.1.4',
#  'v6.2.0',
#  'v6.2.1',
#  'v6.2.2',
#  'v6.2.3',
#  'v6.2.4',
#  'v6.3.0',
#  'v6.3.1',
#  'v6.3.2',
#  'v6.4.0',
#  'v6.4.1',
#  'v6.4.2',
#  'v6.4.3',
#  'v6.5.0',
#  'v6.5.1',
#  'v6.5.2',
#  'v6.5.3',
#  'v6.5.4',
#  'v6.6.0',
#  'v6.6.1',
#  'v6.6.2',
#  'v6.7.0',
#  'v6.7.1',
#  'v6.7.2',
#  'v6.8.0',
#  'v6.8.1',
#  'v6.8.10',
#  'v6.8.11',
#  'v6.8.2',
#  'v6.8.3',
#  'v6.8.4',
#  'v6.8.5',
#  'v6.8.6',
#  'v6.8.7',
#  'v6.8.8',
#  'v6.8.9',
#  'v7.0.0',
#  'v7.0.0-alpha1',
#  'v7.0.0-alpha2',
#  'v7.0.0-beta1',
#  'v7.0.0-rc1',
#  'v7.0.0-rc2',
#  'v7.0.1',
#  'v7.1.0',
#  'v7.1.1',
#  'v7.2.0',
#  'v7.2.1',
#  'v7.3.0',
#  'v7.3.1',
#  'v7.3.2',
#  'v7.4.0',
#  'v7.4.1',
#  'v7.4.2',
#  'v7.5.0',
#  'v7.5.1',
#  'v7.5.2',
#  'v7.6.0',
#  'v7.6.1',
#  'v7.6.2',
#  'v7.7.0',
#  'v7.7.1',
#  'v7.8.0',
#  'v7.8.1']

# %%
runs = 30

# %%
result_folder = "/Users/alexincerti/Code/search.aggregations.bucket/"

# %%
for tag in tags[-4:]:
    tag_name = tag.name
    print(f"Working on tag {tag_name}")
    #
    try:
        git.checkout("-f", tag_name)
    except:
        print(f"Creating a branch for tag {tag_name} and checking it out...")
        git.checkout(tag_name, b=tag_name)
    #
    for run in range(runs):
        print(f"Run {run}...")
        process = subprocess.run(["/Users/alexincerti/Code/elasticsearch/gradlew",
                                  "-p", "/Users/alexincerti/Code/elasticsearch",
                                  ":server:test", 
                                  "--tests",
                                  #"org.apache.lucene.queries.DoubleRandomBinaryDocValuesRangeQueryTests",
                                  "org.elasticsearch.search.aggregations.bucket.missing.*",
                                 f"-Dorg.gradle.java.home={version_jdk[tag_name]}",
                                 "--build-cache"],
                                capture_output=True)
        #
        dest = f'{result_folder}{tag_name}/{run}'
        src = '/Users/alexincerti/Code/elasticsearch/server/build/reports/tests/test'
        if process.returncode == 0:
            if os.path.exists(dest):
                shutil.rmtree(dest)
            #create the folder
            shutil.copytree(src, dest)
        else:
            print(process.stdout)
            print(process.stderr)
print("Finished")
# Out:
# Working on tag v7.7.0
# Run 0...
# Run 1...
# Run 2...
# Run 3...
# Run 4...
# Run 5...
# Run 6...
# Run 7...
# Run 8...
# Run 9...
# Run 10...
# Run 11...
# Run 12...
# Run 13...
# Run 14...
# Run 15...
# Run 16...
# Run 17...
# Run 18...
# Run 19...
# Run 20...
# Run 21...
# Run 22...
# Run 23...
# Run 24...
# Run 25...
# Run 26...
# Run 27...
# Run 28...
# Run 29...
# Working on tag v7.7.1
# Run 0...
# Run 1...
# Run 2...
# Run 3...
# Run 4...
# Run 5...
# Run 6...
# Run 7...
# Run 8...
# Run 9...
# Run 10...
# Run 11...
# Run 12...
# Run 13...
# Run 14...
# Run 15...
# Run 16...
# Run 17...
# Run 18...
# Run 19...
# Run 20...
# Run 21...
# Run 22...
# Run 23...
# Run 24...
# Run 25...
# Run 26...
# Run 27...
# Run 28...
# Run 29...
# Working on tag v7.8.0
# Run 0...
# Run 1...
# Run 2...
# Run 3...
# Run 4...
# Run 5...
# Run 6...
# Run 7...
# Run 8...
# Run 9...
# Run 10...
# Run 11...
# Run 12...
# Run 13...
# Run 14...
# Run 15...
# Run 16...
# Run 17...
# Run 18...
# Run 19...
# Run 20...
# Run 21...
# Run 22...
# Run 23...
# Run 24...
# Run 25...
# Run 26...
# Run 27...
# Run 28...
# Run 29...
# Working on tag v7.8.1
# Run 0...
# Run 1...
# Run 2...
# Run 3...
# Run 4...
# Run 5...
# Run 6...
# Run 7...
# Run 8...
# Run 9...
# Run 10...
# Run 11...
# Run 12...
# Run 13...
# Run 14...
# Run 15...
# Run 16...
# Run 17...
# Run 18...
# Run 19...
# Run 20...
# Run 21...
# Run 22...
# Run 23...
# Run 24...
# Run 25...
# Run 26...
# Run 27...
# Run 28...
# Run 29...
# Finished
